# %% [markdown]
# ## 공공데이터 활용 분석 : 전국 인구 현황 공공데이터 분석

# %%
import csv
f =open('age.csv')
data = csv.reader(f)
next(data)  # 헤더 제거
data[0]  # error DataFrame이 아니여서 에러..
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-bd7705eedbd9> in <module>
#       3 data = csv.reader(f)
#       4 next(data)  # 헤더 제거
# ----> 5 data[0]  # error
#
# TypeError: '_csv.reader' object is not subscriptable

# %%
import csv
f =open('age.csv')
data = csv.reader(f)
next(data)  # 헤더 제거
# Out:
# ['행정구역',
#  '총인구수',
#  '연령구간인구수',
#  '0세',
#  '1세',
#  '2세',
#  '3세',
#  '4세',
#  '5세',
#  '6세',
#  '7세',
#  '8세',
#  '9세',
#  '10세',
#  '11세',
#  '12세',
#  '13세',
#  '14세',
#  '15세',
#  '16세',
#  '17세',
#  '18세',
#  '19세',
#  '20세',
#  '21세',
#  '22세',
#  '23세',
#  '24세',
#  '25세',
#  '26세',
#  '27세',
#  '28세',
#  '29세',
#  '30세',
#  '31세',
#  '32세',
#  '33세',
#  '34세',
#  '35세',
#  '36세',
#  '37세',
#  '38세',
#  '39세',
#  '40세',
#  '41세',
#  '42세',
#  '43세',
#  '44세',
#  '45세',
#  '46세',
#  '47세',
#  '48세',
#  '49세',
#  '50세',
#  '51세',
#  '52세',
#  '53세',
#  '54세',
#  '55세',
#  '56세',
#  '57세',
#  '58세',
#  '59세',
#  '60세',
#  '61세',
#  '62세',
#  '63세',
#  '64세',
#  '65세',
#  '66세',
#  '67세',
#  '68세',
#  '69세',
#  '70세',
#  '71세',
#  '72세',
#  '73세',
#  '74세',
#  '75세',
#  '76세',
#  '77세',
#  '78세',
#  '79세',
#  '80세',
#  '81세',
#  '82세',
#  '83세',
#  '84세',
#  '85세',
#  '86세',
#  '87세',
#  '88세',
#  '89세',
#  '90세',
#  '91세',
#  '92세',
#  '93세',
#  '94세',
#  '95세',
#  '96세',
#  '97세',
#  '98세',
#  '99세',
#  '100세 이상']

# %%
type(data)
# Out:
# _csv.reader

# %%
data = list(data)
len(data), data[0]
# Out:
# (3829,
#  ['서울특별시  (1100000000)',
#   '9857426',
#   '9857426',
#   '61253',
#   '70532',
#   '74322',
#   '72482',
#   '71688',
#   '78941',
#   '75386',
#   '75929',
#   '71772',
#   '76157',
#   '80577',
#   '74502',
#   '72380',
#   '80264',
#   '83081',
#   '83791',
#   '93326',
#   '108584',
#   '105344',
#   '112807',
#   '120957',
#   '125632',
#   '134735',
#   '143930',
#   '149420',
#   '159845',
#   '161550',
#   '150999',
#   '149562',
#   '150485',
#   '146573',
#   '148015',
#   '150838',
#   '149335',
#   '163855',
#   '173092',
#   '173138',
#   '169187',
#   '165335',
#   '139821',
#   '150481',
#   '147416',
#   '150031',
#   '162292',
#   '168414',
#   '171738',
#   '181275',
#   '175113',
#   '172711',
#   '168518',
#   '157576',
#   '144996',
#   '154444',
#   '153733',
#   '146916',
#   '158349',
#   '163134',
#   '168880',
#   '158018',
#   '147497',
#   '147029',
#   '133804',
#   '141178',
#   '119297',
#   '105263',
#   '114400',
#   '80233',
#   '89224',
#   '89871',
#   '88753',
#   '90591',
#   '73185',
#   '64285',
#   '64933',
#   '63515',
#   '74898',
#   '60021',
#   '50860',
#   '49861',
#   '43160',
#   '38593',
#   '34377',
#   '31713',
#   '26206',
#   '21753',
#   '19206',
#   '15377',
#   '13515',
#   '12208',
#   '10165',
#   '8200',
#   '5892',
#   '4695',
#   '3589',
#   '3501',
#   '2569',
#   '1851',
#   '1436',
#   '1010',
#   '736',
#   '5519'])

# %%
import csv
f =open('age.csv')
data = csv.reader(f)
next(data)  # 헤더 제거
for row in data :
    print(row)
    cont = input('Continue(y/n)?')
    if cont=='n': break
# Out:
# ['서울특별시  (1100000000)', '9857426', '9857426', '61253', '70532', '74322', '72482', '71688', '78941', '75386', '75929', '71772', '76157', '80577', '74502', '72380', '80264', '83081', '83791', '93326', '108584', '105344', '112807', '120957', '125632', '134735', '143930', '149420', '159845', '161550', '150999', '149562', '150485', '146573', '148015', '150838', '149335', '163855', '173092', '173138', '169187', '165335', '139821', '150481', '147416', '150031', '162292', '168414', '171738', '181275', '175113', '172711', '168518', '157576', '144996', '154444', '153733', '146916', '158349', '163134', '168880', '158018', '147497', '147029', '133804', '141178', '119297', '105263', '114400', '80233', '89224', '89871', '88753', '90591', '73185', '64285', '64933', '63515', '74898', '60021', '50860', '49861', '43160', '38593', '34377', '31713', '26206', '21753', '19206', '15377', '13515', '12208', '10165', '8200', '5892', '4695', '3589', '3501', '2569', '1851', '1436', '1010', '736', '5519']
# Continue(y/n)?y
# ['서울특별시 종로구 (1111000000)', '154770', '154770', '652', '794', '911', '895', '859', '1046', '909', '1012', '919', '1006', '1089', '1039', '1008', '1110', '1167', '1208', '1374', '1558', '1541', '1884', '2149', '2128', '2287', '2384', '2576', '2636', '2672', '2481', '2304', '2290', '2188', '2131', '2147', '2005', '2191', '2179', '2332', '2219', '2227', '1814', '2018', '2043', '2101', '2393', '2557', '2657', '2953', '2865', '2775', '2710', '2630', '2399', '2618', '2655', '2513', '2649', '2726', '2768', '2529', '2370', '2341', '2175', '2329', '1939', '1706', '1862', '1275', '1465', '1501', '1465', '1618', '1279', '1201', '1206', '1277', '1489', '1266', '1094', '1086', '923', '778', '779', '694', '576', '493', '421', '388', '302', '260', '231', '187', '149', '115', '95', '79', '81', '60', '46', '37', '26', '226']
# Continue(y/n)?y
# ['서울특별시 종로구 청운효자동(1111051500)', '13272', '13272', '81', '82', '90', '105', '97', '116', '117', '116', '102', '119', '144', '123', '108', '135', '126', '139', '138', '172', '171', '164', '161', '193', '168', '159', '169', '171', '179', '154', '151', '191', '147', '178', '190', '168', '168', '197', '243', '216', '232', '190', '209', '218', '227', '223', '268', '253', '261', '245', '246', '231', '235', '209', '228', '205', '196', '184', '200', '192', '186', '157', '151', '147', '161', '126', '127', '137', '82', '113', '118', '107', '127', '111', '104', '98', '106', '121', '99', '91', '104', '83', '74', '76', '58', '55', '51', '30', '30', '13', '24', '18', '12', '12', '14', '7', '7', '8', '3', '5', '1', '1', '17']
# Continue(y/n)?n

# %%
'신도림' in '서울특별시 구로구 신도림동(1153051000)'
# Out:
# True

# %%
'산도림' in '서울특별시 구로구 신도림동(1153051000)'
# Out:
# False

# %%
import csv
f =open('age.csv')
data = csv.reader(f)
next(data)
home = []  #입력 받은 지역의 데이터를 저장할 리스트 생성
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data :
    if name in row[0] : #입력 받은 지역의 이름이 포함된 행 찾기
        for i in row[3:] : #3번 인덱스 값부터 슬라이싱
            home.append(int(i)) #입력 받은 지역의 데이터를 home에 저장
print(home) #home에 저장된 데이터 출력
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 신도림
# [378, 413, 437, 412, 423, 418, 467, 414, 414, 416, 396, 362, 386, 339, 341, 351, 368, 391, 351, 387, 444, 432, 484, 449, 490, 431, 511, 445, 507, 517, 507, 566, 611, 638, 750, 772, 789, 756, 822, 679, 731, 690, 693, 734, 725, 658, 632, 602, 571, 572, 490, 500, 553, 549, 487, 537, 590, 585, 513, 515, 492, 422, 527, 397, 396, 403, 258, 314, 273, 303, 297, 197, 172, 158, 166, 186, 152, 141, 108, 118, 88, 97, 73, 70, 47, 45, 42, 27, 32, 21, 25, 23, 13, 7, 10, 6, 3, 3, 2, 2, 6]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')  # 격자 무늬 스타일 지정 
plt.figure(figsize = (10,5), dpi=100)    
plt.rc('font', family ='Malgun Gothic')
plt.title(name +' 지역의 인구 구조')

plt.plot(home) 
plt.show()

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %% [markdown]
# ## LAB

# %%
import numpy as np
import csv
f =open('age.csv')
data = csv.reader(f)
next(data)
# data = list(data)
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data :
    if name in row[0] :
        home = np.array(row[3:], dtype =int)
#         home = np.array(row[3:], dtype =int) / int(row[2])  #수정

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize = (10,5), dpi=100)    
plt.rc('font', family ='Malgun Gothic')
plt.title(name +' 지역의 인구 구조')

plt.plot(home) 
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 신도림

# %% [markdown]
# ### plot.bar() 사용

# %%
import numpy as np
import csv
f =open('age.csv')
data = csv.reader(f)
next(data)
# data = list(data)
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data :
    if name in row[0] :
        home = np.array(row[3:], dtype =int)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.figure(figsize = (10,5), dpi=100)    
plt.rc('font', family ='Malgun Gothic')
plt.title(name +' 지역의 인구 구조')

plt.bar(range(101), home)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 :

# %%
plt.figure(figsize = (5,10), dpi=100)   
plt.barh(range(101), home)
# Out:
# <BarContainer object of 101 artists>

# %% [markdown]
# ## 전국 인구 현황 공공데이터 분석 : 남녀 성별 인구 분포 분석

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
m = []
f = []
for row in data :
    if name in row[0] :
        for i in range(0,101) :
#            m.append(int(row[i+3]))   
            m.append(-int(row[i+3]))
            f.append(int(row[-(i+1)]))
f.reverse()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 신도림

# %%
print('male:', m)
print('female:', f)
# Out:
# male: [-165, -185, -221, -209, -192, -209, -189, -210, -217, -197, -210, -198, -198, -189, -171, -156, -183, -178, -205, -175, -203, -218, -210, -257, -222, -249, -203, -239, -227, -212, -250, -237, -270, -309, -308, -387, -366, -367, -349, -390, -324, -330, -342, -306, -363, -348, -331, -321, -302, -275, -264, -253, -258, -266, -280, -224, -280, -257, -277, -246, -270, -217, -194, -248, -180, -193, -177, -130, -148, -159, -154, -141, -112, -77, -86, -70, -86, -69, -57, -47, -51, -44, -26, -32, -20, -9, -19, -13, -5, -6, -3, -3, -3, -2, -1, -3, -1, -1, -1, 0, -1]
# female: [152, 164, 195, 195, 200, 206, 227, 222, 195, 198, 201, 190, 161, 174, 161, 178, 166, 163, 203, 193, 192, 220, 218, 256, 235, 216, 239, 255, 229, 268, 305, 296, 306, 318, 336, 369, 393, 441, 382, 396, 355, 357, 355, 321, 366, 351, 303, 327, 329, 299, 299, 246, 247, 294, 240, 222, 258, 307, 280, 268, 263, 238, 224, 269, 201, 185, 225, 140, 143, 120, 118, 143, 86, 85, 74, 84, 87, 69, 73, 67, 63, 53, 60, 46, 44, 31, 29, 29, 21, 25, 18, 12, 11, 10, 3, 7, 3, 2, 1, 3, 6]

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
m = []
f = []
for row in data :
    if name in row[0] :
        for i in range(0,101) :  
            m.append(-int(row[i+3]))
            f.append(int(row[-(i+1)]))
f.reverse()
print('male:', m[:20])
print('female:', f[:20])
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 신도림
# male: [-165, -185, -221, -209, -192, -209, -189, -210, -217, -197, -210, -198, -198, -189, -171, -156, -183, -178, -205, -175]
# female: [152, 164, 195, 195, 200, 206, 227, 222, 195, 198, 201, 190, 161, 174, 161, 178, 166, 163, 203, 193]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rc('font', family = 'Malgun Gothic')
plt.figure(figsize = (5,5), dpi=100) 
plt.barh(range(101), m)
plt.barh(range(101), f)
plt.show()
# Out:
# C:\Users\Yang\Anaconda3\envs\eda\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yang\Anaconda3\envs\eda\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rc('font', family = 'Malgun Gothic')
plt.figure(figsize = (5,5), dpi=100) 
plt.rcParams['axes.unicode_minus'] = False
plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, label = '여성')
plt.legend()
plt.show()

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
m = []
f = []
for row in data :
    if name in row[0] :
        for i in row[3:104] : 
            m.append(-int(i)) # 마이너스 부호를 넣어서 음수로 변경
        for i in row[106:] :            
            f.append(int(i))
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 신도림동

# %%
print('male:', m)
print('female:', f)
# Out:
# male: [-165, -185, -221, -209, -192, -209, -189, -210, -217, -197, -210, -198, -198, -189, -171, -156, -183, -178, -205, -175, -203, -218, -210, -257, -222, -249, -203, -239, -227, -212, -250, -237, -270, -309, -308, -387, -366, -367, -349, -390, -324, -330, -342, -306, -363, -348, -331, -321, -302, -275, -264, -253, -258, -266, -280, -224, -280, -257, -277, -246, -270, -217, -194, -248, -180, -193, -177, -130, -148, -159, -154, -141, -112, -77, -86, -70, -86, -69, -57, -47, -51, -44, -26, -32, -20, -9, -19, -13, -5, -6, -3, -3, -3, -2, -1, -3, -1, -1, -1, 0, -1]
# female: [152, 164, 195, 195, 200, 206, 227, 222, 195, 198, 201, 190, 161, 174, 161, 178, 166, 163, 203, 193, 192, 220, 218, 256, 235, 216, 239, 255, 229, 268, 305, 296, 306, 318, 336, 369, 393, 441, 382, 396, 355, 357, 355, 321, 366, 351, 303, 327, 329, 299, 299, 246, 247, 294, 240, 222, 258, 307, 280, 268, 263, 238, 224, 269, 201, 185, 225, 140, 143, 120, 118, 143, 86, 85, 74, 84, 87, 69, 73, 67, 63, 53, 60, 46, 44, 31, 29, 29, 21, 25, 18, 12, 11, 10, 3, 7, 3, 2, 1, 3, 6]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rc('font', family = 'Malgun Gothic')
plt.figure(figsize = (5,5), dpi=100) 
plt.rcParams['axes.unicode_minus'] = False
plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, label = '여성')
plt.legend()
plt.show()
